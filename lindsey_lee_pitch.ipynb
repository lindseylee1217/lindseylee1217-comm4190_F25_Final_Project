# %% [markdown]
# Have a medical concern that you can’t wait to address in your upcoming medical visit? Meet NurseBot, your home's 24/7 health companion can provide immediate, preliminary analysis of your symptoms to give you more clarity on your health concerns. not a diagnosis tool, but an exploration tool. Just as a nurse asks the right questions to understand the root of your medical concerns, NurseBot uses advanced AI to help you make informed decisions about your health before rushing to the emergency room or urgent care. Through natural conversation, users can describe their symptoms and NurseBot will conduct an assessment by asking relevant follow-up questions and evaluate your symptoms against its comprehensive medical database to provides clear, actionable guidance. NurseBot can also discern urgent health concerns that may require medical attention while providing evidence-based home care instructions for less urgent conditions. NurseBot is not a replacement for a visit to the clinic, but is a handy evidence-based tool to bring healthcare to your home!
# -> send report to HCP
